# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/Users/mac/kc_house_data.csv')

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
print(df.isnull().sum())
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
del df['date']

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
df = df[~((df['price'] < (Q1 - 1.5 * IQR)) | (df['price'] > (Q3 + 1.5 * IQR)))]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# %%
features = ['sqft_living', 'grade', 'sqft_above', 'bathrooms', 'view', 'waterfront', 'bedrooms', 'lat', 'sqft_basement']
impfeat = ['sqft_living']

# %%
X_train = train_data[impfeat]
y_train = train_data['price']

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

# %%
X_test = test_data[impfeat]
y_test = test_data['price']

# %%
y_pred = lr.predict(X_test)

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted Prices (Linear Regression)")
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Mean Squared Error (MSE):", mse)
print("R-squared value:", r2)
# Out:
# Mean Squared Error (MSE): 26199914865.890427
# R-squared value: 0.3708605458534663

# %%
mlr = LinearRegression()

# %%
X_train = train_data[features]
y_train = train_data['price']

# %%
X_test = test_data[features]
y_test = test_data['price']

# %%
mlr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_mlr = mlr.predict(X_test)

# %%
mse_mlr = mean_squared_error(y_test, y_pred_mlr)
r2_mlr = r2_score(y_test, y_pred_mlr)

# %%
print("Mean Squared Error (MSE) - Multiple Linear Regression:", mse_mlr)
print("R-squared value - Multiple Linear Regression:", r2_mlr)
# Out:
# Mean Squared Error (MSE) - Multiple Linear Regression: 22197847572.998795
# R-squared value - Multiple Linear Regression: 0.4669623250002958

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.fit_transform(X_test)

# %%
plr = LinearRegression()

# %%
plr.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
y_pred_poly = plr.predict(X_test_poly)

# %%
mse_poly = mean_squared_error(y_test, y_pred_poly)
r2_poly = r2_score(y_test, y_pred_poly)

print("Mean Squared Error (MSE) - Polynomial Regression:", mse_poly)
print("R-squared value - Polynomial Regression:", r2_poly)
# Out:
# Mean Squared Error (MSE) - Polynomial Regression: 21895208935.3083
# R-squared value - Polynomial Regression: 0.4742295969855239
